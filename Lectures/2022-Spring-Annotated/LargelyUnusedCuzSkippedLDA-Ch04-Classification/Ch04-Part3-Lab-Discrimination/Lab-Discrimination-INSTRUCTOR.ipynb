# %% [markdown]
# # Lab: Discrimination
# ## CMSE 381 - Spring 2022
# ## Jan 28, 2022

# %% [markdown]
# ##ANSWER##
# This lab was developed using material from https://embeddedethics.seas.harvard.edu/cs-181-2021-spring
#
# Notes from Liz 2/3/22:
# I didn't plan this far enough ahead.  Next time, I would assign reading from the big law review paper to get students in the right mindset in advance. So this module is being developed without pre-class assignment and I'm kinda regretting it. We'll see how this first pass goes and hopefully I can revise it for the next time.

# %% [markdown]
# In this module, we will discuss discrimination, and how it manifests, intentionally and unintentionally, with the creationg of maching learning systems like we've been discussing in class. Someday, you will finish this class, and someday after that, you will graduate.  Someday, you may be in the position where you are implementing the ideas you've learned in this class in real-life systems, where the models you build potentially alter the course of someone's life. It is important to understand how the inner workings of the systems we build can accidentally discover and exacerbate inequalities in society.

# %% [markdown]
# ## Materials:
#
# - This module will largely use the following paper as a reference.  https://www.californialawreview.org/wp-content/uploads/2016/06/2Barocas-Selbst.pdf

# %% [markdown]
# # Questions
#
# Using the above article as a guide, discuss and answer the following questions with your group. I also encourage googling as you discuss.

# %% [markdown]
# ## Q1
# What is discrimination?

# %% [markdown]
# *Include your notes and thoughts here*

# %% [markdown]
# ##ANSWER##
#
# - Disrimination can be mornally neutral, in the sense that all stats models are discriminatory.
# - Wrongful discrimination defn: *the unjust or prejudicial treatment of different categories of people or things, especially on the grounds of race, age, or sex.*
# -

# %% [markdown]
# ## Q2
# What is disparate treatment? What is disparate impact? Use Section II of the Barocas-Selbast article, to guide your discussion. Provide examples of each.

# %% [markdown]
# *Include your notes and thoughts here*

# %% [markdown]
# ##ANSWER##
#
# ### Disparate treatment
#
# - liability for both explicit formal classification and intentional discrimination.
# - Formal discrimination means membership of protected class used as input to the model
# -
#
# ### Disparate impact
#
# - No discriminatory intent, but still impacts protected class differently

# %% [markdown]
# ## Q3
# Suppose that the age at which someone starts computer programming is strongly correlated with future success as a software engineer at Google. On average, boys tend to start computer programming earlier than girls.
#
# - Would it be discriminatory for Google to use the age at which someone starts computer programming as part of their basis for deciding which software engineers to hire?
# - Would it be illegal?
# - Would it be unfair?

# %% [markdown]
# *Include your notes and thoughts here*

# %% [markdown]
# ##ANSWER##
#
# Based on the previous discussion, this falls under disparate impact.

# %% [markdown]
# ## Q4
#
# Consider the following map of Boston's access to Amazon Same-Day delivery from 2016. This image is from [this news article](https://www.bloomberg.com/graphics/2016-amazon-same-day/). Spend some time reading the article before you answer the questions.
#
# ![Blue region shows where Amazon same-day delivery reaches](https://imgur.com/ugJui0m.png)
#
# ![More information about Amazon same-day delivery in Boston](https://i.imgur.com/zEDOon5.png "Boston")
#
# Some people think that Amazon’s process for determining which neighborhoods would receive same-day delivery was wrongfully discriminatory, but others disagree. What do you think? Explain your reasoning.

# %% [markdown]
# *Include your notes and thoughts here*

# %% [markdown]
# ## Q5
#
# Is it possible for a learning model to be both *accurate* and *discriminatory*?

# %% [markdown]
# *Include your notes and thoughts here*

# %% [markdown]
# ##ANSWER##
#
# Yes, this goes under the garbage in garbage out problem.
#
# Accurate: making the correct prediction given the data
#
# Discriminatory: From intro - *data mining can discover surprisingly useful regularities that are really just preexisting patterns of exclusion and inequality.*

# %% [markdown]
# ## Q6
# Basing decisions about how to treat others on social group membership often strikes us as wrongfully discriminatory. For example, most people would say that refusing to hire someone because they are a woman is wrongful discrimination, at least under normal circumstances. However, there are cases in which deciding how to treat people on the basis of social group membership does not strike most people as unfair, even if it ends up disadvantaging members of one group relative to another. Describe one such case – it can be a real-world case, or a hypothetical scenario of your own devising – and explain why someone might think the treatment in question is not discriminatory.

# %% [markdown]
# *Include your notes and thoughts here*

# %%
##ANSWER## 
# This cell gets the name of the current notebook. Needs a sec
# to run before it works

from jupyterinstruct import InstructorNotebook
this_notebook = InstructorNotebook.getname()


##ANSWER##

# %%
##ANSWER##
#This cell runs the converter which removes ANSWER fields, renames the notebook and cleans out output fields. 

studentnotebook = InstructorNotebook.makestudent(this_notebook)
InstructorNotebook.validate(studentnotebook)
# Out:
# Myfilename Lab-Discrimination-INSTRUCTOR.ipynb
# Lab-Discrimination.ipynb
# <a href=./Lab-Discrimination.ipynb target="blank">./Lab-Discrimination.ipynb</a>
# Validating Notebook ./Lab-Discrimination.ipynb
#    ERROR: Link not found - https://www.californialawreview.org/wp-content/uploads/2016/06/2Barocas-Selbst.pdf
# 1
