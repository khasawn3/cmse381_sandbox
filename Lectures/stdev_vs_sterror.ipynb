# %%
import numpy as np
import pandas as pd

# %%
mylist = [1,2,3,4]

np.std(mylist)
# Out:
# 1.118033988749895

# %%
np.std(mylist, ddof=1)
# Out:
# 1.2909944487358056

# %%
pd.Series(mylist).sem()
# Out:
# 0.6454972243679028
